# %%
import pandas as pd

# %%
df=pd.read_csv('All_Courses_In_Germany.csv',delimiter=';')

# %%
pd.set_option('display.max_colwidth', None)

# %%
df.sample(1)
# Out:
#      Course ID     Course Name Course Short Name  \
# 660       4677  Expanded Media    Expanded Media
#
#                                     Subject Name  \
# 660  Performing Arts, Film and Television, Drama
#
#                              University Name  City Name  \
# 660  Darmstadt University of Applied Sciences   Dieburg
#
#     Teaching languages Instruction Required German language  \
# 660                        English                     None
#
#     Required English language                         Beginning  \
# 660                      None  Winter semester, Summer semester
#
#         Duration of Programme Tuition Fees  \
# 660  3 semesters, 4 semesters         none
#
#                                                                            Course Details Link
# 660  https://www2.daad.de/deutschland/studienangebote/international-programmes/en/detail/4677/

# %%
filt=['data analytics','business analytics','data analysis','business intelligence']

# %%
da=df[
    (df['Course Name'].str.contains('|'.join(filt),case=False)) &\
    (df['Subject Name'].isin(['Business and Economics','Computer Science']))
  ]
da.head(1)
# Out:
#      Course ID                          Course Name         Course Short Name  \
# 294       6944  Business Analytics (BSc), full-time  Business Analytics (BSc)
#
#                Subject Name  \
# 294  Business and Economics
#
#                                                  University Name  City Name  \
# 294  SRH University of Applied Sciences in North Rhine-Westphalia      Hamm
#
#     Teaching languages Instruction Required German language  \
# 294                        English                     None
#
#     Required English language                         Beginning  \
# 294                      None  Winter semester, Summer semester
#
#     Duration of Programme Tuition Fees  \
# 294           6 semesters         4080
#
#                                                                            Course Details Link
# 294  https://www2.daad.de/deutschland/studienangebote/international-programmes/en/detail/6944/

# %%
da.shape
# Out:
# (17, 13)

# %% [markdown]
# ## There are 17 courses offered in the field of analytics

# %%
da['Required German language'].value_counts()
# Out:
# None    17
# Name: Required German language, dtype: int64

# %% [markdown]
# ## None of the courses in data analytics require german language

# %%
df_free=da[~da['Tuition Fees'].str.isdigit()]

# %%
len(df_free)
# Out:
# 8

# %% [markdown]
# ## There are only 8 courses in analytics that have zero tuition fees

# %%
df_free
# Out:
#       Course ID  \
# 302        4529
# 414        5561
# 1606       8423
# 1607       8556
# 1755       4407
# 1779       8516
# 1792       5148
# 1907       4777
#
#                                                                                                                                                Course Name  \
# 302                                                                                                     Business Intelligence and Process Management (MSc)
# 414                                                                                                                                   Data Analytics (MSc)
# 1606                                                                                     Master's in Business Analytics & Econometrics – Master of Science
# 1607                                                                                                                  Master's in Business Analytics (MSc)
# ...

# %%
df_free.drop(columns=['Required German language','Required English language'],inplace=True)
# Out:
# /Users/ayushlingwal/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_free=df_free.reset_index(drop=True)

# %%
df_free
# Out:
#    Course ID  \
# 0       4529
# 1       5561
# 2       8423
# 3       8556
# 4       4407
# 5       8516
# 6       5148
# 7       4777
#
#                                                                                                                                             Course Name  \
# 0                                                                                                    Business Intelligence and Process Management (MSc)
# 1                                                                                                                                  Data Analytics (MSc)
# 2                                                                                     Master's in Business Analytics & Econometrics – Master of Science
# 3                                                                                                                  Master's in Business Analytics (MSc)
# ...

# %%
df_free.to_csv('/Users/ayushlingwal/Pandas Projects/german uni courses/Data Analytics.csv',index=False)
